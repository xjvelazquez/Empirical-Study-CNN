# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# #### Prepare for Dataset

# %%
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Get some random training images.
dataiter = iter(trainloader)
images, labels = dataiter.next()
# Show images.
imshow(torchvision.utils.make_grid(images))
# Print labels.
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# truck  deer truck   cat

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %% [markdown]
# #### Network Definition

# %%
net = torch.hub.load('pytorch/vision:v0.6.0', 'alexnet', pretrained=True)
net.classifier[6].out_features = 10
net.eval()
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Downloading: "https://github.com/pytorch/vision/archive/v0.6.0.zip" to /tmp/xdg-cache/torch/hub/v0.6.0.zip
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /tmp/xdg-cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# 100%|██████████| 233M/233M [00:01<00:00, 160MB/s]
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# #### Optimizer and Loss Function

# %%
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss()  
# We use stochastic gradient descent (SGD) as optimizer.
opt = optim.Adam(net.parameters(), lr=0.0001) #, momentum=0.9)

# %% [markdown]
# #### Training Procedure

# %%
avg_losses = []   # Avg. losses.
epochs = 10       # Total epochs.
print_freq = 1000  # Print frequency.

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_loss = 0.0       # Initialize running loss.
    for i, data in enumerate(trainloader, 0):
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step.
        outputs = net(inputs)
        loss = loss_func(outputs, labels)
        
        # Backward step.
        loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()

        # Print statistics.
        running_loss += loss.item()
        if i % print_freq == print_freq - 1: # Print every several mini-batches.
            avg_loss = running_loss / print_freq
            print('[epoch: {}, i: {:5d}] avg mini-batch loss: {:.3f}'.format(
                epoch, i, avg_loss))
            avg_losses.append(avg_loss)
            running_loss = 0.0

print('Finished Training.')
# Out:
# [epoch: 0, i:   999] avg mini-batch loss: 1.300
# [epoch: 0, i:  1999] avg mini-batch loss: 0.861
# [epoch: 0, i:  2999] avg mini-batch loss: 0.743
# [epoch: 0, i:  3999] avg mini-batch loss: 0.691
# [epoch: 0, i:  4999] avg mini-batch loss: 0.688
# [epoch: 0, i:  5999] avg mini-batch loss: 0.646
# [epoch: 0, i:  6999] avg mini-batch loss: 0.617
# [epoch: 0, i:  7999] avg mini-batch loss: 0.592
# [epoch: 0, i:  8999] avg mini-batch loss: 0.586
# [epoch: 0, i:  9999] avg mini-batch loss: 0.578
# [epoch: 0, i: 10999] avg mini-batch loss: 0.567
# [epoch: 0, i: 11999] avg mini-batch loss: 0.545
# [epoch: 1, i:   999] avg mini-batch loss: 0.375
# [epoch: 1, i:  1999] avg mini-batch loss: 0.400
# [epoch: 1, i:  2999] avg mini-batch loss: 0.412
# [epoch: 1, i:  3999] avg mini-batch loss: 0.413
# [epoch: 1, i:  4999] avg mini-batch loss: 0.421
# [epoch: 1, i:  5999] avg mini-batch loss: 0.405
# [epoch: 1, i:  6999] avg mini-batch loss: 0.432
# [epoch: 1, i:  7999] avg mini-batch loss: 0.394
# [epoch: 1, i:  8999] avg mini-batch loss: 0.389
# [epoch: 1, i:  9999] avg mini-batch loss: 0.381
# [epoch: 6, i:  6999] avg mini-batch loss: 0.150
# [epoch: 6, i:  7999] avg mini-batch loss: 0.155
# [epoch: 6, i:  8999] avg mini-batch loss: 0.137
# [epoch: 6, i:  9999] avg mini-batch loss: 0.181
# [epoch: 6, i: 10999] avg mini-batch loss: 0.150
# [epoch: 6, i: 11999] avg mini-batch loss: 0.132
# [epoch: 7, i:   999] avg mini-batch loss: 0.107
# [epoch: 7, i:  1999] avg mini-batch loss: 0.114
# [epoch: 7, i:  2999] avg mini-batch loss: 0.125
# [epoch: 7, i:  3999] avg mini-batch loss: 0.113
# [epoch: 7, i:  4999] avg mini-batch loss: 0.148
# [epoch: 7, i:  5999] avg mini-batch loss: 0.098
# [epoch: 7, i:  6999] avg mini-batch loss: 0.150
# [epoch: 7, i:  7999] avg mini-batch loss: 0.149
# [epoch: 7, i:  8999] avg mini-batch loss: 0.164
# [epoch: 7, i:  9999] avg mini-batch loss: 0.133
# [epoch: 7, i: 10999] avg mini-batch loss: 0.128
# [epoch: 7, i: 11999] avg mini-batch loss: 0.166
# [epoch: 8, i:   999] avg mini-batch loss: 0.107
# [epoch: 8, i:  1999] avg mini-batch loss: 0.111
# [epoch: 8, i:  2999] avg mini-batch loss: 0.127
# [epoch: 8, i:  3999] avg mini-batch loss: 0.115
# [epoch: 8, i:  4999] avg mini-batch loss: 0.111
# [epoch: 8, i:  5999] avg mini-batch loss: 0.144
# [epoch: 8, i:  6999] avg mini-batch loss: 0.143
# [epoch: 8, i:  7999] avg mini-batch loss: 0.137
# [epoch: 8, i:  8999] avg mini-batch loss: 0.122
# [epoch: 8, i:  9999] avg mini-batch loss: 0.131
# [epoch: 8, i: 10999] avg mini-batch loss: 0.162
# [epoch: 8, i: 11999] avg mini-batch loss: 0.103
# [epoch: 9, i:   999] avg mini-batch loss: 0.089
# [epoch: 9, i:  1999] avg mini-batch loss: 0.119
# [epoch: 9, i:  2999] avg mini-batch loss: 0.097
# [epoch: 9, i:  3999] avg mini-batch loss: 0.118
# [epoch: 9, i:  4999] avg mini-batch loss: 0.123
# [epoch: 9, i:  5999] avg mini-batch loss: 0.151
# [epoch: 9, i:  6999] avg mini-batch loss: 0.110
# [epoch: 9, i:  7999] avg mini-batch loss: 0.124
# [epoch: 9, i:  8999] avg mini-batch loss: 0.132
# [epoch: 9, i:  9999] avg mini-batch loss: 0.183
# [epoch: 9, i: 10999] avg mini-batch loss: 0.140
# [epoch: 9, i: 11999] avg mini-batch loss: 0.136
# Finished Training.

# %% [markdown]
# #### Training Loss Curve

# %%
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %% [markdown]
# #### Evaluate on Test Dataset

# %%
# Check several images.
dataiter = iter(testloader)
images, labels = dataiter.next()
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
outputs = net(images.to(device))
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat  ship  ship plane

# %%
# Get test accuracy.
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 85 %

# %%
# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 83 %
# Accuracy of   car : 93 %
# Accuracy of  bird : 84 %
# Accuracy of   cat : 58 %
# Accuracy of  deer : 92 %
# Accuracy of   dog : 83 %
# Accuracy of  frog : 89 %
# Accuracy of horse : 89 %
# Accuracy of  ship : 89 %
# Accuracy of truck : 88 %
